# %%
from IStrategy import *
from BacktestEngine import *
from MarketUtils import *
from Configuration import *
from DistanceStrategy import *
import matplotlib.pyplot as plt 
from CointegrationStrategy import *
from CopulaStrategy import *
import pandas as pd
from statsmodels.tsa.stattools import coint
tradingperiod = 30
formation = 126
indices = ['^GSPC', '^IXIC']
termDates = ['01-01-2002','01-01-2015']
price_data = get_data(type ='index',col_list = indices, termDates = termDates)
alter_data = get_data(type = 'alter', termDates = termDates)
price_data = price_data.loc[alter_data.index.values]
strategy = CointegrationStrategy(factor=2, formation=formation,tradingperiod=tradingperiod,indices = indices)
backtest = backtest_walk_forward(price_data, alter_data, strategy)
returns = backtest.run_backtest()
backtest.doAnalytics()
spread = strategy.get_spread()
hlf = strategy.get_half_life()
spread.index = price_data.index[-len(spread):]
hlf.index = price_data.index[-len(spread):]
# Out:
# c:\Users\Lakshay Garg\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-064d23ce6556> in <module>
#      18 strategy = CointegrationStrategy(factor=2, formation=formation,tradingperiod=tradingperiod,indices = indices)
#      19 backtest = backtest_walk_forward(price_data, alter_data, strategy)
# ---> 20 returns = backtest.run_backtest()
#      21 backtest.doAnalytics()
#      22 spread = strategy.get_spread()
#
# ...

# %%
# Out:
# c:\Users\Lakshay Garg\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-121b226c4f15> in <module>
#       8 strategy = CointegrationStrategy(factor=2, formation=formation,tradingperiod=tradingperiod,indices = indices)
#       9 backtest = backtest_walk_forward(price_data, alter_data, strategy)
# ---> 10 returns = backtest.run_backtest()
#      11 backtest.doAnalytics()
#      12 spread = strategy.get_spread()
#
# ...

# %%
s = backtest._price_data
s = (s - s.mean())/s.std()
print(s)
# Out:
#                ^GSPC      ^RUA
# Date
# 2002-01-02 -0.433599 -0.605576
# 2002-01-03 -0.396276 -0.569397
# 2002-01-04 -0.370783 -0.543852
# 2002-01-07 -0.397614 -0.569566
# 2002-01-08 -0.412332 -0.578568
# ...              ...       ...
# 2014-12-24  2.831191  2.762952
# 2014-12-26  2.855452  2.788722
# 2014-12-29  2.861790  2.797555
# 2014-12-30  2.825805  2.764021
# 2014-12-31  2.750277  2.696333
#
# [3242 rows x 2 columns]
# c:\Users\Lakshay Garg\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# c:\Users\Lakshay Garg\Anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <AxesSubplot: xlabel='Date'>
